# %%
import geopandas as gpd
import pandas as pd
import requests
import math
import numpy
from datetime import datetime
from shapely import wkt
from shapely.errors import WKTReadingError
from shapely.geometry import mapping, shape
from shapely import Polygon
import warnings
warnings.filterwarnings("ignore")

# %%
gdf = gpd.read_file(r"C:\Users\dorito\Music\LEIDER TEMP\Carpeta del P\shp\Lote.shp")

# %%
gdf["documento"] = gdf["documento"].apply(lambda x: str(int(x)) if pd.notnull(x) else "")

# %%
gdf.to_file(r"C:\Users\dorito\Music\LEIDER TEMP\Carpeta del P\shp\Lote.shp")
